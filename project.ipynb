# %%
from numpy import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("worldcities.csv")
x=np.array([1,2,3,4,5,6,7])
z=np.arange(1,100)
y1=x^2+5
y2=x^3-5

# %%
df.shape
# Out:
# (7322, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7322 entries, 0 to 7321
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     7322 non-null   object
#  1   Country  7322 non-null   object
# dtypes: object(2)
# memory usage: 114.5+ KB

# %%
#show the duplicate row 
dup = df[df.duplicated()]
dup
# Out:
#              City                   Country
# 1115  St. Charles  United States of America
# 1447      Windsor                    Canada
# 1713       Suzhou                     China
# 2119  Springfield  United States of America
# 2201     Columbia  United States of America
# ...           ...                       ...
# 7085     Mazatlan                    Mexico
# 7110        Crato                    Brazil
# 7143       Rostov                    Russia
# 7157    Jamestown  United States of America
# 7161   Charleston  United States of America
#
# [72 rows x 2 columns]

# %%
#data cleaning remove missing data
z=df.dropna()
z
# Out:
#                       City                   Country
# 0                Rovaniemi                   Finland
# 1                Steinkjer                    Norway
# 2                 Monterey  United States of America
# 3                     Kuta                 Indonesia
# 4                    Lovec                  Bulgaria
# ...                    ...                       ...
# 7317                De Aar              South Africa
# 7318  Kamensk Shakhtinskiy                    Russia
# 7319                 Sinop                    Turkey
# 7320              Tirupati                     India
# 7321              Huangshi                     China
#
# [7322 rows x 2 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7322, step=1)

# %%
df.columns
# Out:
# Index(['City', 'Country'], dtype='object')

# %%
df.describe()
# Out:
#             City                   Country
# count       7322                      7322
# unique      7063                       223
# top     Victoria  United States of America
# freq           5                       769

# %%
df.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of                       City                   Country
# 0                Rovaniemi                   Finland
# 1                Steinkjer                    Norway
# 2                 Monterey  United States of America
# 3                     Kuta                 Indonesia
# 4                    Lovec                  Bulgaria
# ...                    ...                       ...
# 7317                De Aar              South Africa
# 7318  Kamensk Shakhtinskiy                    Russia
# 7319                 Sinop                    Turkey
# 7320              Tirupati                     India
# 7321              Huangshi                     China
#
# [7322 rows x 2 columns]>

# %%
plt.subplot(1,2,1)
plt.plot(x,y1,c="r",linestyle=':',linewidth=5)
plt.title("char1")
plt.xlabel("data")
plt.ylabel("shape1")
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x,y2,c="g",linestyle=':',linewidth=5)
plt.title("char2")
plt.xlabel("data")
plt.ylabel("shape2")
plt.grid(True)
plt.show()

# %%
plt.scatter(x,y2,c="b",marker="*")
plt.scatter(x,y1,c="black",marker="+")
plt.grid(True)
plt.show()

# %%
name={"a":8,"d":88,"c":78,"n":98}
v1=list(name.keys())
v2=list(name.values())
plt.bar(v1,v2)
plt.show()
